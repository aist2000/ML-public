# %% [markdown]
# <a href="https://colab.research.google.com/github/aist2000/ML-public/blob/master/ANG_Ex1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal

import numpy as np

# %%
print("Andrew Ng Linear Regression")
# Out:
# Andrew Ng Linear Regression

# %%
import pandas as pd

# %%
url="https://raw.githubusercontent.com/aist2000/ml-test/master/py/machine-learning-ex1/ex1data1.txt"
data = pd.read_csv(url, header=None)
data.head()
data.describe()
# Out:
#                0          1
# count  97.000000  97.000000
# mean    8.159800   5.839135
# std     3.869884   5.510262
# min     5.026900  -2.680700
# 25%     5.707700   1.986900
# 50%     6.589400   4.562300
# 75%     8.578100   7.046700
# max    22.203000  24.147000

# %%
data.head()

x = data[0]
y = data[1]

plt.scatter(x,y)

# %%
x
# Out:
# 0      6.1101
# 1      5.5277
# 2      8.5186
# 3      7.0032
# 4      5.8598
# 5      8.3829
# 6      7.4764
# 7      8.5781
# 8      6.4862
# 9      5.0546
# 10     5.7107
# 11    14.1640
# 12     5.7340
# 13     8.4084
# 14     5.6407
# 15     5.3794
# 16     6.3654
# 17     5.1301
# 18     6.4296
# 19     7.0708
# 20     6.1891
# 21    20.2700
# 22     5.4901
# 23     6.3261
# 24     5.5649
# 25    18.9450
# 26    12.8280
# 27    10.9570
# 28    13.1760
# 29    22.2030
#        ...
# 67    10.2360
# 68     5.4994
# 69    20.3410
# 70    10.1360
# 71     7.3345
# 72     6.0062
# 73     7.2259
# 74     5.0269
# 75     6.5479
# 76     7.5386
# 77     5.0365
# 78    10.2740
# 79     5.1077
# 80     5.7292
# 81     5.1884
# 82     6.3557
# 83     9.7687
# 84     6.5159
# 85     8.5172
# 86     9.1802
# 87     6.0020
# 88     5.5204
# 89     5.0594
# 90     5.7077
# 91     7.6366
# 92     5.8707
# 93     5.3054
# 94     8.2934
# 95    13.3940
# 96     5.4369
# Name: 0, Length: 97, dtype: float64

# %% [markdown]
# **Scipy Linear Regression**

# %%
from scipy import stats

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)

# %%
x1_value = min(x)
x2_value = max(x)
y1_value = intercept + slope * x1_value
y2_value = intercept + slope * x2_value

x1_value, x2_value,y1_value, y2_value
# Out:
# (5.0269, 22.203000000000003, 2.1014799476648154, 22.593145123629704)

# %%
plt.scatter(data[0],data[1])
plt.plot( [x1_value, x2_value],[y1_value, y2_value], 'r')

# %% [markdown]
# **Scilearn Linear Regression**

# %%
from sklearn import datasets, linear_model

# %%
#length = len(x.index) 

xl = x.values.reshape(-1, 1)
yl = y.values.reshape(-1, 1)

# Create linear regression object
regr = linear_model.LinearRegression()

#x = [1,2,3]
#y = [1,2,3]

# Train the model using the training sets
regr.fit( xl,  yl)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
plt.scatter(data[0],data[1])
#plt.plot( [x1_value, x2_value],[y1_value, y2_value], 'r')
plt.plot(xl, regr.predict(xl), color='red', linewidth=1)
